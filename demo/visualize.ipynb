# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = '../configs/polarmask/4gpu/polar_768_1x_x101.py'
checkpoint_file = '../checkpoints/x101_1x.pth'
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# /home/mary/PolarMask/mmdet/models/anchor_heads/polarmask_head.py:72: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   self.angles = torch.range(0, 350, 10).cuda() / 180 * math.pi

# %%
img = '../data/coco/val2017/000000025560.jpg'
result = inference_detector(model, img)
show_result_pyplot(img, result, model.CLASSES)
#show_result_pyplot(model.CLASSES, img, result)
print("END!!!")
# Out:
# END!!!
